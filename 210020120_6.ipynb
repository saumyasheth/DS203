# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('master.csv')
display(df)
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %% [markdown]
# ### Q 1 a)

# %%
filter1 = df['age'] == '15-24 years'
filter2 = df['age'] == '35-54 years'
filter3 = df['age'] == '75+ years'
filter4 = df['age'] == '25-34 years'
filter5 = df['age'] == '55-74 years'
filter6 = df['age'] == '5-14 years'
suicideno = [sum(df[filter1].iloc[:,4]),sum(df[filter2].iloc[:,4]),sum(df[filter3].iloc[:,4]),sum(df[filter4].iloc[:,4]),sum(df[filter5].iloc[:,4]),sum(df[filter6].iloc[:,4])]
plt.bar(df['age'].unique(),suicideno)
plt.title('No. of suicides in each age group')
ab = plt.gca()
for tick in ab.get_xticklabels(): 
    tick.set_rotation(90)
plt.show()

# %%
f1 = df['sex'] == 'male'
f2 = df['sex'] == 'female'
sexwisesuicide = [sum(df[f1].iloc[:,4]),sum(df[f2].iloc[:,4])]
plt.bar(df['sex'].unique(),sexwisesuicide)
plt.title('male vs female no. of suicides')
plt.show()

# %% [markdown]
# ### Q 1 b) i)

# %%
print(df[df.columns[0]].mode())
print(df[df.columns[1]].mode())
#print(df[df.columns[2]].mode())
#print(df[df.columns[3]].mode())
print(df[df.columns[4]].mode()) ###doubtful
#print(df[df.columns[7]].mode())
print(df[df.columns[8]].mode())
#print(df[df.columns[9]].mode())
#print(df[df.columns[10]].mode())
print(df[df.columns[11]].mode())
# Out:
# 0        Austria
# 1        Iceland
# 2      Mauritius
# 3    Netherlands
# Name: country, dtype: object
# 0    2009
# Name: year, dtype: int64
# 0    0
# Name: suicides_no, dtype: int64
# 0    0.713
# 1    0.772
# 2    0.888
# Name: HDI for year, dtype: float64
# 0    Generation X
# Name: generation, dtype: object

# %% [markdown]
# ### Q 1) b) ii)

# %%
import math
arr = df.iloc[:,0].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,0].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[0] + ' ' + str(s))
arr = df.iloc[:,1].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,1].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[1] + ' ' + str(s))  
arr = df.iloc[:,2].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,2].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[2] + ' ' + str(s))  
arr = df.iloc[:,3].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,3].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[3] + ' ' + str(s))  
arr = df.iloc[:,4].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,4].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[4] + ' ' + str(s))  

arr = df.iloc[:,7].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,7].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[7] + ' ' + str(s))
from math import nan, isnan
list_without_nan = [x for x in df.iloc[:,8] if isnan(x) == False] 
df1 = pd.DataFrame(list_without_nan, columns = ['HDI for year'])
arr = df1.iloc[:,0].unique()
s=0
for i in range(len(arr)):
    p = (df1.iloc[:,0].value_counts()[arr[i]])/8364
    s = s - p*math.log(p)
print(df.columns[8] + ' ' + str(s))
arr = df.iloc[:,9].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,9].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[9] + ' ' + str(s))  
arr = df.iloc[:,10].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,10].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[10] + ' ' + str(s))  
arr = df.iloc[:,11].unique()
s=0
for i in range(len(arr)):
    p = (df.iloc[:,11].value_counts()[arr[i]])/27820
    s = s - p*math.log(p)
print(df.columns[11] + ' ' + str(s))
# Out:
# country 4.512115046503916
# year 3.432956123756321
# sex 0.6931471805599453
# age 1.7917561564428144
# suicides_no 5.243743260095325
# country-year 7.74965239401791
# HDI for year 5.55426124913362
#  gdp_for_year ($)  7.74965239401791
# gdp_per_capita ($) 7.69646011794513
# generation 1.695449187635522

# %% [markdown]
# ### Q 1) c) i)

# %%
for i in range(4,7):
    print(df.columns[i] + ' mean : ' + str(df.iloc[:,i].mean()))
for i in range(4,7):
    print(df.columns[i] + ' variance : ' + str(df.iloc[:,i].var()))
# Out:
# suicides_no mean : 242.57440690150972
# population mean : 1844793.6173975556
# suicides/100k pop mean : 12.816097411933864
# suicides_no variance : 813690.4442639101
# population variance : 15302018400947.725
# suicides/100k pop variance : 359.538899953126

# %%
dfcont = df.iloc[:,4:7].describe()
print(dfcont)
print()
#print('mean : ')
#print(dfcont.iloc[1,:])
#print()
for i in range(4,7):
    print(df.columns[i] + ' variance : ' + str(df.iloc[:,i].var()))
print()
for i in range(4,7):
    print(df.columns[i] + ' skew : ' + str(df.iloc[:,i].skew()))  
print()
#print('min : ')
#print(dfcont.iloc[3,:])
#print()
#print('max : ')
#print(dfcont.iloc[7,:])
interquart = np.empty(3)
for i in range(3):
    interquart[i] = dfcont.iloc[6,i] - dfcont.iloc[4,i]      
for i in range(4,7):
    print(df.columns[i] + ' inter quartile range : ' + str(interquart[i-4]))
# Out:
#         suicides_no    population  suicides/100k pop
# count  27820.000000  2.782000e+04       27820.000000
# mean     242.574407  1.844794e+06          12.816097
# std      902.047917  3.911779e+06          18.961511
# min        0.000000  2.780000e+02           0.000000
# 25%        3.000000  9.749850e+04           0.920000
# 50%       25.000000  4.301500e+05           5.990000
# 75%      131.000000  1.486143e+06          16.620000
# max    22338.000000  4.380521e+07         224.970000
#
# suicides_no variance : 813690.4442639101
# population variance : 15302018400947.725
# suicides/100k pop variance : 359.538899953126
#
# suicides_no skew : 10.352910335856805
# population skew : 4.459414421535874
# suicides/100k pop skew : 2.963414476605633
#
# suicides_no inter quartile range : 128.0
# population inter quartile range : 1388644.75
# suicides/100k pop inter quartile range : 15.700000000000001

# %% [markdown]
# ### Q 1) c) ii)

# %%
continous = [df.columns[4],df.columns[5],df.columns[6]]
for items in continous:
    plt.boxplot(np.log(df[items])) 
    plt.show()
# Out:
# c:\Users\ADMIN\Documents\ds203\my_name\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\ADMIN\Documents\ds203\my_name\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ### Q 1) c) iii)

# %%
for i in range(4,7):
    plt.title(df.columns[i])
    plt.hist(df.iloc[:,i],10)
    plt.show()
    plt.title(df.columns[i])
    plt.hist(df.iloc[:,i],len(pd.unique(df.iloc[:,i])))
    plt.show()
    plt.title(df.columns[i])
    plt.hist(df.iloc[:,i],50)
    plt.show()

# %% [markdown]
# ### Q 1) d) ii)

# %%
corr = df.iloc[:,4:7].corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(10, 5, n=20),
    square=True
)

# %% [markdown]
# ### Q 2) a)

# %%
avg = np.empty(df.iloc[:,0].nunique(),float)
j = 0
for i in df.iloc[:,0].unique():
    filter = df['country'] == i
    total = df[filter].iloc[:,4].sum()
    years = df[filter].iloc[:,1].max() - df[filter].iloc[:,1].min() + 1
    avg[j] = total/years
    j = j+1
#np.argmax(avg)
N = 6
  
# Indices of N largest elements in list
# using sorted() + lambda + list slicing
res = sorted(range(len(avg)), key = lambda sub: avg[sub])[-N:]
  
# printing result
#print("Indices list of max 6 elements is : " + str(res))
j = 5
listofmaxcountries = np.empty(6,object)  
for i in range(6):
    listofmaxcountries[i] = df.iloc[:,0].unique()[res[j]] 
    j = j-1
listofmaxcountries     
#avgcopy = np.empty(len(avg) - 1,float)
#for i in range(len(avg) - 1):
#    avgcopy[i] = avg[i]
#avgcopy.sort()
#topindex = np.empty(6,int)
#for i in range(1,7):
#    print(avg1.index(avgcopy[len(avgcopy) - i]))
#topindex
# Out:
# array(['Russian Federation', 'United States', 'Japan', 'Germany',
#        'Ukraine', 'France'], dtype=object)

# %% [markdown]
# ### Q 2) b)

# %%
res.reverse()
res
j=0
for i in listofmaxcountries:
    filter = df.iloc[:,0] == i
    filter1 = df[filter]['age'] == '15-24 years'
    filter2 = df[filter]['age'] == '35-54 years'
    filter3 = df[filter]['age'] == '75+ years'
    filter4 = df[filter]['age'] == '25-34 years'
    filter5 = df[filter]['age'] == '55-74 years'
    filter6 = df[filter]['age'] == '5-14 years'
    suicideno = [sum(df[filter][filter1].iloc[:,4]),sum(df[filter][filter2].iloc[:,4]),sum(df[filter][filter3].iloc[:,4]),sum(df[filter][filter4].iloc[:,4]),sum(df[filter][filter5].iloc[:,4]),sum(df[filter][filter6].iloc[:,4])]
    plt.bar(df['age'].unique(),suicideno)
    plt.title(listofmaxcountries[j])
    ab = plt.gca()
    for tick in ab.get_xticklabels(): 
        tick.set_rotation(90)
    plt.show()
    j = j+1

# %% [markdown]
# ### Q 2) c)

# %%
filt1 = df.iloc[:,2] == 'male'
filt2 = df.iloc[:,2] == 'female'
df1 = df[filt1].groupby(by='year').sum()
df2 = df[filt2].groupby(by='year').sum()
sns.lineplot(x=df1.index, y=df1['suicides/100k pop'], label='male')
sns.lineplot(x=df2.index, y=df2['suicides/100k pop'], label='female')
# Out:
# <AxesSubplot:xlabel='year', ylabel='suicides/100k pop'>

# %%
df.iloc[:,11].unique()
# Out:
# array(['Generation X', 'Silent', 'G.I. Generation', 'Boomers',
#        'Millenials', 'Generation Z'], dtype=object)

# %% [markdown]
# ### Q 2) d)

# %%
filtus = df.iloc[:,0] == 'United States'
filtgen = df.iloc[:,11] == 'Generation X'
suicavg = np.empty(31)
years = np.empty(31)
for i in range(1985,2016):
    
    filteryear = df[filtus][filtgen].iloc[:,1] == i
    sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
    sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
    suicavg[i-1985] = sumsuicide/sumpopulation
    years[i-1985] = i
plt.bar(years,suicavg)
plt.title('Generation X')
plt.show() 

filtgen = df.iloc[:,11] == 'Silent'


for i in range(1985,2016):
    
    filteryear = df[filtus][filtgen].iloc[:,1] == i
    sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
    sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
    suicavg[i-1985] = sumsuicide/sumpopulation
    years[i-1985] = i
plt.bar(years,suicavg)
plt.title('Silent')
plt.show() 
filtgen = df.iloc[:,11] == 'G.I. Generation'


for i in range(1985,2016):
    
    filteryear = df[filtus][filtgen].iloc[:,1] == i
    sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
    sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
    suicavg[i-1985] = sumsuicide/sumpopulation
    years[i-1985] = i
plt.bar(years,suicavg)
plt.title('G.I. Generation')
plt.show() 
filtgen = df.iloc[:,11] == 'Boomers'


for i in range(1985,2016):
    
    filteryear = df[filtus][filtgen].iloc[:,1] == i
    sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
    sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
    suicavg[i-1985] = sumsuicide/sumpopulation
    years[i-1985] = i
plt.bar(years,suicavg)
plt.title('Boomers')
plt.show() 
filtgen = df.iloc[:,11] == 'Millenials'


for i in range(1985,2016):
    
    filteryear = df[filtus][filtgen].iloc[:,1] == i
    sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
    sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
    suicavg[i-1985] = sumsuicide/sumpopulation
    years[i-1985] = i
plt.bar(years,suicavg)
plt.title('Millenials')
plt.show() 
filtgen = df.iloc[:,11] == 'Generation Z'


for i in range(1985,2016):
    
    filteryear = df[filtus][filtgen].iloc[:,1] == i
    sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
    sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
    suicavg[i-1985] = sumsuicide/sumpopulation
    years[i-1985] = i
plt.bar(years,suicavg)
plt.title('Generation Z')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_56060\932843767.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filteryear = df[filtus][filtgen].iloc[:,1] == i
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_56060\932843767.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sumsuicide = df[filtus][filtgen][filteryear].iloc[:,4].sum()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_56060\932843767.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sumpopulation = df[filtus][filtgen][filteryear].iloc[:,5].sum()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_56060\932843767.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filteryear = df[filtus][filtgen].iloc[:,1] == i
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_56060\932843767.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %% [markdown]
# ### Q 2) e)

# %%
df2 = df.groupby(['year','country','sex','age']).sum()
df3 = df2.xs(2000,level='year')
df3 = df3.reset_index()
countries = ['Albania','United Kingdom','Japan','Bulgaria','Poland',"Croatia","Hungary"]
for country in countries:
    df4 = df3.loc[df3['country']==country]
    df_male = df4.loc[df4['sex']=='male'][['population','age']]
    df_female = df4.loc[df4['sex']=='female'][['population','age']]
    df_merge = pd.merge(df_male, df_female, on='age')
    df_male.reset_index(drop=True,inplace=True)
    df_female.reset_index(drop=True,inplace=True)
    df_merge = df_merge[['age','population_x','population_y']]
    fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10,5))
    for ax, column, color, invert in zip(axes.ravel(), ['population_x','population_y'], ['maroon', 'orange'],  [False,True]):
        ax.bar(df_merge['age'],df_merge[column],  color=color)
        plt.xticks(rotation=90)
        ax.set(xlabel='age group',ylabel='Population')
        if invert:
            ax.invert_yaxis()
        else :
            ax.set_title(country)
        plt.subplots_adjust(hspace=0)

# %% [markdown]
# ### Q 2) f)

# %%
df.iloc[:,8] = df.iloc[:,8].fillna(0)
x = df.iloc[:,6]
y = df.iloc[:,8]
z = np.log10(np.log10(df.iloc[:,5]))
colors = np.random.rand(27820) 
# use the scatter function
plt.scatter(x, y, s=z*1000,c=colors, alpha = 0.2)
plt.show()
